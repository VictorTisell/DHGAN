# %%
from dhgan import DHGAN
import pandas as pd
import datetime
import QuantLib as ql

# %%
symbol_list = ['^GSPC', '^VIX', '^NDX', '^RUT', '^DJI',
                '^FVX','^TNX', '^TYX', 'EURUSD=X','JPY=X']
settings = {'module':'gru',
            'hidden_dim':24,
            'latent_dim': 5,
            'num_layers': 3,
            'iterations': 10000,
            'batch_size': 100,
            'learning_rate':0.001}
DH_settings = {'hedge_simulations': 1000000,
                'hedge_features': 2,
                'hedge_epochs': 2,
                'hedge_batch_size': 1000,
                'hedge_neurons': 70,
                'hedge_learning_rate': 0.0001,
                'hedge_validation_proportion':0.1,
                'hedge_test_proportion':0.001,
                'alpha':0.5,
                'epsilon':0.0,
                'strike':3200}
datafolder_path = 'datafolder'
filename = 'quotedata_SPX.csv'
filepath = datafolder_path + '/' + filename
option_data = pd.read_csv(filepath, sep = ';')
calendar = ql.UnitedStates()
Ks = [3000, 3100, 3200, 3300, 3400]
ttms = [10, 21, 31]
option_settings = {'start': datetime.date(2020,9,11),
            'day_count': ql.Actual365Fixed(),
            'calendar': ql.UnitedStates(),
            'strikes': Ks,
            'maturities':ttms}
Model = DHGAN(symbol_list,settings, DH_settings, option_data ,option_settings)

model_names = ['Generator', 'Supervisor', 'Recovery', 'dhmodel']
Model.train(model_names, save = True)
# Out:
# /Users/victortisell/Documents/GitHub/DHGAN/src/utils.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ttm'] = df.index - self.ql_to_dt(self.start_ql)
# /Users/victortisell/Documents/GitHub/DHGAN/src/utils.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ttm'] = df['ttm'].dt.days
# Model: "EmbedderNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 31, 10)            660
# _________________________________________________________________
# gru_1 (GRU)                  (None, 31, 24)            2592
# _________________________________________________________________
# gru_2 (GRU)                  (None, 31, 24)            3600
# _________________________________________________________________
# gru_3 (GRU)                  (None, 31, 24)            3600
# _________________________________________________________________
# time_distributed (TimeDistri (None, 31, 5)             125
# =================================================================
# Total params: 10,577
# Trainable params: 10,577
# Non-trainable params: 0
# _________________________________________________________________
# Model: "RecoveryNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_4 (GRU)                  (None, 31, 24)            2232
# _________________________________________________________________
# gru_5 (GRU)                  (None, 31, 24)            3600
# _________________________________________________________________
# gru_6 (GRU)                  (None, 31, 24)            3600
# _________________________________________________________________
# gru_7 (GRU)                  (None, 31, 24)            3600
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 31, 10)            250
# =================================================================
# Total params: 13,282
# Trainable params: 13,282
# Non-trainable params: 0
# _________________________________________________________________
# Model: "SupervisorNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_8 (GRU)                  (None, 31, 24)            2232
# _________________________________________________________________
# gru_9 (GRU)                  (None, 31, 24)            3600
# _________________________________________________________________
# gru_10 (GRU)                 (None, 31, 24)            3600
# _________________________________________________________________
# gru_11 (GRU)                 (None, 31, 24)            3600
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 31, 5)             125
# =================================================================
# Total params: 13,157
# Trainable params: 13,157
# Non-trainable params: 0
# _________________________________________________________________
# Model: "GeneratorNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_12 (GRU)                 (None, 31, 24)            2592
# _________________________________________________________________
# gru_13 (GRU)                 (None, 31, 24)            3600
# _________________________________________________________________
# gru_14 (GRU)                 (None, 31, 24)            3600
# _________________________________________________________________
# gru_15 (GRU)                 (None, 31, 24)            3600
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 31, 5)             125
# =================================================================
# Total params: 13,517
# Trainable params: 13,517
# Non-trainable params: 0
# _________________________________________________________________
# Model: "DiscriminatorNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_16 (GRU)                 (None, 31, 24)            2232
# _________________________________________________________________
# gru_17 (GRU)                 (None, 31, 24)            3600
# _________________________________________________________________
# gru_18 (GRU)                 (None, 31, 24)            3600
# _________________________________________________________________
# gru_19 (GRU)                 (None, 31, 24)            3600
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 31, 5)             125
# =================================================================
# Total params: 13,157
# Trainable params: 13,157
# Non-trainable params: 0
# _________________________________________________________________
# Model: "DeepHedgeNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 31, 10)]     0
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 70)           17220       input_1[0][0]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 9, 70)        0           gru_20[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 20, 70)       0           gru_20[0][0]
# __________________________________________________________________________________________________
# repeat_vector_2 (RepeatVector)  (None, 30, 70)       0           gru_20[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 9, 70)        29820       repeat_vector[0][0]
# __________________________________________________________________________________________________
# gru_22 (GRU)                    (None, 20, 70)       29820       repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# gru_23 (GRU)                    (None, 30, 70)       29820       repeat_vector_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 9, 10)        710         gru_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 20, 10)       710         gru_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 30, 10)       710         gru_23[0][0]
# ==================================================================================================
# Total params: 108,810
# Trainable params: 108,810
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Initiating EmbedderNet Pre-training
# Batch training (embedder) loss at iteration 0: 0.1173
# ---------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-2d669583278c> in <module>
#      34
#      35 model_names = ['Generator', 'Supervisor', 'Recovery', 'dhmodel']
# ---> 36 Model.train(model_names, save = True)
#
# ~/Documents/GitHub/DHGAN/src/dhgan.py in train(self, model_names, save)
#     397             X_batch = self.sample_batch(self.norm_data)
#     398             _embedder_loss = self.Embedder_train_step(X_batch)
# --> 399             if iteration % 1000 == 0:
#     400                 print('Batch training (embedder) loss at iteration %d: %.4f'% (iteration, float(np.sqrt(_embedder_loss))))
#     401                 print('---------------------------------------------------------------')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
